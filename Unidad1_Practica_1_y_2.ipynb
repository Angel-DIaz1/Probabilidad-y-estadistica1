# %% [markdown]
# <a href="https://colab.research.google.com/github/Angel-DIaz1/Probabilidad-y-estadistica1/blob/main/Unidad1_Practica_1_y_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from statistics import *
# lista de calificaciones del grupo a de probabilidad y estadistica
grupos = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print(grupos)

type(grupos)

promedio = sum(grupos) / len(grupos)
print(promedio)

promedio2 = mean(grupos)
print(promedio2)

mediana = median(grupos)
print(mediana)

moda = mode(grupos)
print(moda)

moda2 = multimode(grupos)
print(moda2)

tiempos100mts = [15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.10, 17.20]
print(tiempos100mts)

print("el tiempo promedio de los corredores es=>", mean(tiempos100mts) )

mediana = median(tiempos100mts)
print("la media de los  tiempos de los corredores es=>", mediana )

moda = multimode(tiempos100mts)
print(" la moda de los tiempos es=>", moda)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
# 75.33333333333333
# 75.33333333333333
# 76.5
# 70
# [70, 100]
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]
# el tiempo promedio de los corredores es=> 17.322
# la media de los  tiempos de los corredores es=> 17.2
#  la moda de los tiempos es=> [15.1, 17.2]

# %%
import random

fabrica1 = []
for i in range(100):
   numero_aleatorio = round( random.uniform(50, 100), 2)
   fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [63.13, 85.83, 63.6, 91.95, 58.29, 64.97, 82.58, 98.21, 69.98, 63.52, 62.67, 56.4, 58.02, 52.29, 91.57, 78.46, 93.33, 57.51, 62.13, 61.13, 78.6, 96.37, 80.6, 98.86, 63.75, 94.66, 94.7, 77.66, 58.2, 91.87, 80.31, 79.57, 80.46, 85.6, 59.51, 53.9, 57.06, 75.43, 51.25, 91.04, 72.47, 67.98, 78.2, 75.37, 94.0, 96.04, 53.35, 50.61, 50.37, 94.49, 61.62, 59.4, 54.58, 89.24, 57.61, 61.14, 94.63, 75.16, 70.76, 77.08, 95.03, 91.44, 67.89, 63.38, 61.88, 50.26, 98.56, 74.53, 89.1, 68.15, 80.51, 51.93, 99.78, 75.85, 53.22, 57.88, 52.62, 86.65, 92.44, 94.96, 96.43, 61.57, 87.16, 62.03, 56.27, 68.19, 60.71, 96.57, 54.58, 79.03, 77.5, 68.23, 68.21, 86.07, 69.79, 65.3, 85.83, 73.97, 88.78, 76.37]

# %%
import random

fabrica2 = []
for i in range(100):
   numero_aleatorio = round( random.uniform(50, 100), 2)
   fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [96.84, 87.5, 98.64, 65.48, 65.95, 73.27, 69.16, 85.02, 63.58, 64.18, 76.27, 99.39, 67.79, 80.86, 87.12, 89.05, 52.05, 83.47, 79.7, 80.27, 87.94, 76.07, 65.48, 87.55, 88.78, 90.13, 71.15, 52.08, 88.82, 93.17, 92.2, 52.92, 55.38, 96.19, 69.62, 91.97, 63.41, 68.13, 62.73, 57.49, 75.88, 93.55, 85.34, 81.21, 71.87, 64.15, 75.98, 54.68, 97.35, 74.81, 99.53, 81.92, 81.54, 76.94, 56.59, 70.39, 82.27, 54.82, 85.19, 69.03, 55.05, 73.37, 53.35, 64.31, 78.05, 59.87, 82.58, 59.78, 86.22, 68.28, 86.88, 90.35, 65.9, 91.74, 58.79, 69.97, 96.36, 59.13, 96.78, 69.04, 55.06, 64.41, 69.81, 77.17, 64.48, 68.73, 53.56, 91.05, 93.8, 60.82, 77.3, 54.92, 87.48, 91.49, 66.45, 99.09, 97.95, 77.83, 74.99, 66.03]

# %%
import matplotlib.pyplot as plt


plt.hist(fabrica1)
plt.title("produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'produccion diaria de la fabrica 1')

# %%
import matplotlib.pyplot as plt

plt.hist(fabrica2)
plt.title("produccion diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'produccion diaria de la fabrica 2')

# %%
from statistics import *

media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("valores de la fabrica 1")
print("la media es =", media1)
print("la mediana es =", mediana1)
print("la moda es=", moda1)
# Out:
# valores de la fabrica 1
# la media es = 73.8772
# la mediana es = 74.25
# la moda es= 85.83

# %%
from statistics import *

media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("valores de la fabrica 2")
print("la media es =", media2)
print("la mediana es =", mediana2)
print("la moda es=", moda2)
# Out:
# valores de la fabrica 2
# la media es = 75.6806
# la mediana es = 75.93
# la moda es= 65.48

# %%
fig, (ax1, ax2) = plt.subplots(nrows =1, ncols=2, figsize=(10, 5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='mediana')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='mediana')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label='moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diria de la fabrica 2")
plt.legend()
plt.show()
